# %%
import numpy as np
import scipy
from matplotlib.pyplot import *
from scipy import *
from scipy import stats

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.display import clear_output, display, HTML

# %%
ion()

# %%
from bvn import BivariateNormal, plot_bvn, plot_bvn_rho

# %%
plot_bvn(.75, regress=2., samples=300)
# Out:
# (<matplotlib.figure.Figure at 0x10d048f28>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a1252e400>)

# %%
widget = interactive(plot_bvn_rho, rho=(-.95, .95))

# %%
display(widget)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='rho', max=0.95, min=-0.95), Output()), _dom_classes=('widget-interact',))
